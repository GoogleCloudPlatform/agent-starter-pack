# %% [markdown]
# # CrewAI Agent - Local Example
#
# Quick local testing notebook for CrewAI agent with utility tools.

# %% [markdown]
# ## Setup
#
# Import the agent and helper functions.

# %%
import sys
sys.path.append('../')

from {{cookiecutter.agent_directory}}.agent import (
    run_agent,
    get_current_time,
    calculate,
    analyze_text,
    generate_ideas,
    assistant_agent
)

# %% [markdown]
# ## Test Individual Tools
#
# Test each tool independently.

# %%
# Test time tool
print("Time Tool:")
print(get_current_time.run())
print()

# Test calculator tool
print("Calculator Tool:")
print(calculate.run(expression="2 + 2"))
print()

# Test text analyzer tool
print("Text Analyzer Tool:")
print(analyze_text.run(text="This is a great example!"))
print()

# Test agent info
print("Agent Info:")
print(f"Role: {assistant_agent.role}")
print(f"Goal: {assistant_agent.goal}")
print(f"Tools: {len(assistant_agent.tools)}")

# %% [markdown]
# ## Simple Time Query
#
# Test with a simple time-based query.

# %%
query = "What time is it?"
response = run_agent(query)
print(f"Query: {query}")
print(f"Response: {response}")

# %% [markdown]
# ## Test Calculation
#
# Test the calculator tool through the agent.

# %%
query = "What is 15 * 23 + 47?"

print(f"Query: {query}")
response = run_agent(query)
print(f"Response: {response}")

# %% [markdown]
# ## Custom Query
#
# Try your own query.

# %%
# Enter your own query here
custom_query = "{{cookiecutter.example_question}}"

print(f"Query: {custom_query}")
response = run_agent(custom_query)
print(f"\nResponse: {response}")
